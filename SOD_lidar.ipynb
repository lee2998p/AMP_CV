# %%
import numpy as np

# %%
# %cd drive/MyDrive/Grade\ 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring
# Out:
# /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring

# %%
data = np.load('train_file05_0000000261.npy')
x = data[:, 0]
y = data[:, 1]
z = data[:, 2]

import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import proj3d

fig = plt.figure(figsize=(16, 9))
ax = fig.add_subplot(111, projection='3d')

img = ax.scatter(x, y, z, c=data[:,4], cmap=plt.hot())
fig.colorbar(img)
plt.show()

# %% [markdown]
# ![Screen Shot 2022-04-29 at 5.01.08 PM.png](data:image/png;base64,...)
