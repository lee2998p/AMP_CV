# %%
from IPython.display import display, Image

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring'
# /content

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.
# /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5
#      |████████████████████████████████| 596 kB 4.2 MB/s

# %%
# !python detect.py --weights yolov5s.pt --source data/Small\ Obstacle\ Detection/Seoyoung_dataset
# Out:
# ...
# detect: weights=['yolov5s.pt'], source=data/Small Obstacle Detection/Seoyoung_dataset, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/306 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/Seoyoung_dataset/0000000000.png: 384x640 Done. (0.275s)
# image 2/306 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/Seoyoung_dataset/0000000001.png: 384x640 Done. (0.254s)
# ...

# %%
# !python detect.py --weights yolov5n.pt --source data/Small\ Obstacle\ Detection/Seoyoung_dataset
# Out:
# detect: weights=['yolov5n.pt'], source=data/Small Obstacle Detection/Seoyoung_dataset, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/306 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/Seoyoung_dataset/0000000000.png: 384x640 1 person, Done. (0.140s)
# image 2/306 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/Seoyoung_dataset/0000000001.png: 384x640 Done. (0.106s)
# ...

# %%
# !python detect.py --weights yolov5n.pt --source data/Small\ Obstacle\ Detection/train_file_1
# Out:
# detect: weights=['yolov5n.pt'], source=data/Small Obstacle Detection/train_file_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/291 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/train_file_1/0000000080.png: 384x640 3 persons, 1 car, Done. (0.143s)
# image 2/291 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/train_file_1/0000000081.png: 384x640 2 persons, 1 car, Done. (0.110s)
# ...

# %%
# !python detect.py --weights yolov5s.pt --source data/Small\ Obstacle\ Detection/train_file_1
# Out:
# detect: weights=['yolov5s.pt'], source=data/Small Obstacle Detection/train_file_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/291 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/train_file_1/0000000080.png: 384x640 1 person, 2 cars, Done. (0.286s)
# ...

# %%
# !python detect.py --weights yolov5m.pt --source data/Small\ Obstacle\ Detection/train_file_1
# Out:
# detect: weights=['yolov5m.pt'], source=data/Small Obstacle Detection/train_file_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# ...
# 100% 40.8M/40.8M [00:00<00:00, 83.8MB/s]
#
# Fusing layers...
# Model Summary: 290 layers, 21172173 parameters, 0 gradients, 49.0 GFLOPs
# image 1/291 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/train_file_1/0000000080.png: 384x640 3 persons, 3 cars, Done. (0.744s)
# ...

# %%
# !python detect.py --weights yolov5n6.pt --source data/Small\ Obstacle\ Detection/train_file_1
# Out:
# detect: weights=['yolov5n6.pt'], source=data/Small Obstacle Detection/train_file_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# ...
# 100% 6.86M/6.86M [00:00<00:00, 31.4MB/s]
#
# Fusing layers...
# Model Summary: 280 layers, 3239884 parameters, 0 gradients, 4.6 GFLOPs
# image 1/291 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/train_file_1/0000000080.png: 384x640 1 person, 2 cars, Done. (0.156s)
# ...

# %%
# !python detect.py --weights yolov5n.pt --source data/Small\ Obstacle\ Detection/val_vindhya_1
# Out:
# detect: weights=['yolov5n.pt'], source=data/Small Obstacle Detection/val_vindhya_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 1867405 parameters, 0 gradients, 4.5 GFLOPs
# image 1/73 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/val_vindhya_1/0000000257.png: 384x640 Done. (0.137s)
# image 2/73 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/val_vindhya_1/0000000261.png: 384x640 1 person, Done. (0.103s)
# ...

# %%
# !python detect.py --weights yolov5s.pt --source data/Small\ Obstacle\ Detection/val_vindhya_1
# Out:
# detect: weights=['yolov5s.pt'], source=data/Small Obstacle Detection/val_vindhya_1, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 2022-3-4 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# image 1/73 /content/drive/MyDrive/Grade 4-2/VIP Senior Design 2/AMP ML Team/2022 Spring/yolov5/data/Small Obstacle Detection/val_vindhya_1/0000000257.png: 384x640 1 person, 1 boat, 1 bench, Done. (0.314s)
# ...
